# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
data1 = {'customer_id':['6732', '767', '890', '635'],
    'month':['Jan-20', 'Jan-20', 'Jan-20', 'Jan-20'],
    'purchased_meat':[0, 13, 3, 4],
    'purchased_alcohol':[1, 2, 10, 0],
    'purchased_snacks':[10, 5, 1, 7]}

# %%
data2 = {'customer_id':['6732', '767', '890', '635'],
    'month':['Feb-20', 'Feb-20', 'Feb-20', 'Feb-20'],
    'purchased_meat':[0, 10, 5, 3],
    'purchased_alcohol':[2, 4, 14, 0],
    'purchased_snacks':[15, 3, 2, 6]}

# %%
df = pd.DataFrame(data1,index=[0, 1, 2, 3])

# %%
df_1 = pd.DataFrame(data2,index=[0, 1, 2, 3])

# %%
df
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7

# %%
df_1
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %%
frames=[df,df_1]

# %%
pd.concat(frames)
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %%
pd.concat(frames, axis = 1)
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
#
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %%
pd.merge=pd.merge(df,df_1, on = ['customer_id', 'month'], indicator = True)

# %%
pd.merge

# %% [markdown]
# __Clean data__

# %%
df_orders_clean = pd.read_csv(r'C:\Users\hp\Desktop\Task 4\Task 4.2\Instacart Basket Analysis\02 Data\Prepared Data\df_orders_clean.csv', index_col = False)

# %%
path= r'C:\Users\hp\Desktop\Task 4\Task 4.2\Instacart Basket Analysis'

# %%
df_ords_prior= pd.read_csv(r'C:\Users\hp\Desktop\order_products__prior.csv', index_col = False)

# %%
df_ords_prior
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %%
df_orders_clean
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                 0   2539329        1    prior             1
# 1                 1   2398795        1    prior             2
# 2                 2    473747        1    prior             3
# 3                 3   2254736        1    prior             4
# 4                 4    431534        1    prior             5
# ...             ...       ...      ...      ...           ...
# 3421078     3421078   2266710   206209    prior            10
# 3421079     3421079   1854736   206209    prior            11
# 3421080     3421080    626363   206209    prior            12
# 3421081     3421081   2977660   206209    prior            13
# 3421082     3421082    272231   206209    train            14
#
#          order_day_of_week  order_hour_of_day  days_since_prior_order
# 0                        2                  8                     1.0
# 1                        3                  7                    15.0
# ...

# %% [markdown]
# __Merge data__

# %%
df_merged_large= df_orders_clean.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large
# Out:
#           Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                  0   2539329        1    prior             1
# 1                  0   2539329        1    prior             1
# 2                  0   2539329        1    prior             1
# 3                  0   2539329        1    prior             1
# 4                  0   2539329        1    prior             1
# ...              ...       ...      ...      ...           ...
# 32434484     3421081   2977660   206209    prior            13
# 32434485     3421081   2977660   206209    prior            13
# 32434486     3421081   2977660   206209    prior            13
# 32434487     3421081   2977660   206209    prior            13
# 32434488     3421081   2977660   206209    prior            13
#
#           order_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                         2                  8                     1.0
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# __Directions__

# %% [markdown]
# _Export the merged file in pickle format as “orders_products_combined.pkl._

# %%
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# __The rest of task in next file__
