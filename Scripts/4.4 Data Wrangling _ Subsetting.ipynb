# %% [markdown]
# # The training

# %%
import pandas as pd
import numpy as np
import os

# %%
df_orders = pd.read_csv(r'C:\Users\hp\Desktop\Task 4\Task 4.2\Instacart Basket Analysis\02 Data\Original Data\orders.csv', index_col = False)

# %%
df_prods = pd.read_csv(r'C:\Users\hp\Desktop\Task 4\Task 4.2\Instacart Basket Analysis\02 Data\Original Data\products.csv', index_col = False)

# %%
df_departments = pd.read_csv(r'C:\Users\hp\Desktop\Task 4\Task 4.2\Instacart Basket Analysis\02 Data\Original Data\departments.csv', index_col = False)

# %%
df_departments.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
path= r'C:\Users\hp\Desktop\Task 4\Task 4.2\Instacart Basket Analysis'

# %%
df_orders.drop(columns = ['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
df_orders.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
df_departments_T= df_departments.T

# %%
df_orders['order_id'] = df_orders['order_id'].astype('str')

# %%
df_departments_T.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
new_header = df_departments_T.iloc[0]

# %%
df_departments_T.head()
# Out:
#                         0
# department_id  department
# 1                  frozen
# 2                   other
# 3                  bakery
# 4                 produce

# %%
df_departments_t_new = df_departments_T[1:]

# %%
df_departments_t_new.head()
# Out:
#          0
# 1   frozen
# 2    other
# 3   bakery
# 4  produce
# 5  alcohol

# %%
df_departments_t_new.columns= new_header

# %%
df_departments_t_new.head()
# Out:
# department_id department
# 1                 frozen
# 2                  other
# 3                 bakery
# 4                produce
# 5                alcohol

# %%
df_departments_t_new.to_dict('index')
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
data_dict=df_departments_t_new.to_dict('index')

# %%
print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %%
df_prods[df_prods['department_id']==19]
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
df_prods['department_id']==19
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %%
df_snacks_2 = df_prods.loc[df_prods['department_id'] == 19]

# %% [markdown]
# # EXERCISE

# %%
## Find another identifier variable and change it to a suitable format

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                object
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   orders_day_of_week      int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 182.7+ MB

# %%
df_orders['order_id'] = df_orders['order_id'].astype('str')
df_orders['user_id'] = df_orders['user_id'].astype('str')

# %%
## Look for a variable with an unintuitive name and change its name without overwriting the data frame.

# %%
df_orders.rename(columns = {'orders_day_of_week' : 'order_day_of_week'}, inplace = True)

# %%
df_orders.head()
# Out:
#   order_id user_id eval_set  order_number  order_day_of_week  \
# 0  2539329       1    prior             1                  2
# 1  2398795       1    prior             2                  3
# 2   473747       1    prior             3                  3
# 3  2254736       1    prior             4                  4
# 4   431534       1    prior             5                  4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
##  the busiest hour is for placing orders

# %%
df_orders['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_hour_of_day, dtype: int64

# %%
10 AM is the the busiest hour
# Out:
#   Cell In[32], line 1
#     10 AM is the the busiest hour
#        ^
# SyntaxError: invalid syntax

# %%
## Determine the meaning behind a value of 4 in the "department_id" column

# %%
data_dict=df_departments_t_new.to_dict('index')

# %%
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %%
## Create a subset containing only the required information.(breakfast item sales)

# %%
df_bf = df_prods[df_prods['department_id']==14]

# %%
df_bf.head(50)
# Out:
#       product_id                                       product_name  aisle_id  \
# 27            28                                  Wheat Chex Cereal       121
# 33            34                                                NaN       121
# 67            68                            Pancake Mix, Buttermilk       130
# 89            90                                       Smorz Cereal       121
# 210          211   Gluten Free Organic Cereal Coconut Maple Vanilla       130
# 215          216                  Gluten Free Oatmeal, Variety Pack       130
# 221          222                          Honey Nut Oatmeal Squares       121
# 237          238                       Alpha-Bits Multigrain Cereal       121
# 251          252                                 Waffles, Red Berry       121
# 287          288  Original Sprouted Grains Protein & Fiber Hot O...       130
# 339          340                         Eco-Pac Kamut Puffs Cereal       121
# ...

# %%
## find all observations include items: alcohol, deli, beverages, and meat/seafood and present this subset to your client.

# %%
df_departments_T.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %% [markdown]
# so I need to use (5,20,7,12)

# %%
df_alcohol= df_prods[df_prods['department_id']==5]

# %%
df_alcohol.head()
# Out:
#      product_id                    product_name  aisle_id  department_id  \
# 51           52             Mirabelle Brut Rose       134              5
# 118         119          Chardonnay Paso Robles        62              5
# 149         150                       Brut Rosé       134              5
# 233         234               Tennessee Whiskey       124              5
# 248         249  Pinot Grigio, California, 2010        62              5
#
#      prices
# 51     14.4
# 118     5.5
# 149    12.9
# 233     3.1
# 248     2.7

# %%
df_deli= df_prods[df_prods['department_id']==20]

# %%
df_deli.head()
# Out:
#      product_id                                   product_name  aisle_id  \
# 48           49  Vegetarian Grain Meat Sausages Italian - 4 CT        14
# 61           62        Premium Deli Oven Roasted Turkey Breast        96
# 73           74                Artisan Chick'n & Apple Sausage        14
# 84           85                           Soppressata Piccante        96
# 108         109                         Grape Leaf Hummus Wrap        13
#
#      department_id  prices
# 48              20    10.1
# 61              20    14.6
# 73              20     3.0
# 84              20     8.9
# 108             20     7.1

# %%
df_beverages= df_prods[df_prods['department_id']==7]

# %%
df_beverages.head()
# Out:
#     product_id                                    product_name  aisle_id  \
# 2            3            Robust Golden Unsweetened Oolong Tea        94
# 6            7                  Pure Coconut Water With Orange        98
# 9           10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                               Peach Mango Juice        31
# 19          20  Pomegranate Cranberry & Aloe Vera Enrich Drink        98
#
#     department_id  prices
# 2               7     4.5
# 6               7     4.4
# 9               7     8.4
# 10              7     2.8
# 19              7     6.0

# %%
df_meat_seafood= df_prods[df_prods['department_id']==12]

# %%
df_meat_seafood.head()
# Out:
#     product_id                                       product_name  aisle_id  \
# 16          17                                  Rendered Duck Fat        35
# 22          23                             Organic Turkey Burgers        49
# 34          35     Italian Herb Porcini Mushrooms Chicken Sausage       106
# 39          40  Beef Hot Links Beef Smoked Sausage With Chile ...       106
# 83          84                                         Lamb Shank         7
#
#     department_id  prices
# 16             12    17.1
# 22             12     8.2
# 34             12    15.1
# 39             12    22.5
# 83             12    24.3

# %%
df_all = df_prods.loc[df_prods['department_id'].isin([5,12,20,7])]

# %%
df_all
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %%
## How many rows does the last dataframe you created have?

# %% [markdown]
# 7650 rows * 5 columns

# %%
## Extract all the information you can about user 1

# %%
df_user_1 = df_orders.loc[df_orders['user_id'].isin ([1])]

# %%
df_user_1.describe

# %%
## Exporting

# %%
df_orders.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))

# %%
df_departments_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.csv'))
