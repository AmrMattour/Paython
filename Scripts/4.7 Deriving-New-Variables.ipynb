# %%
import pandas as pd
import numpy as np
import os

# %%
# Define function

def add_num(x,y):
    sum= x+y
    return sum

# %%
add_num(9,11)
# Out:
# 20

# %%
9+11
# Out:
# 20

# %% [markdown]
# __Import data__

# %%
orders_products_merged = pd.read_pickle(r'C:\Users\hp\Desktop\Task 4\Task 4.2\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_merged-003.PKL')

# %%
orders_products_merged
# Out:
#           order_id  user_id eval_set  order_number  order_day_of_week  \
# 0          2539329        1    prior             1                  2
# 1          2398795        1    prior             2                  3
# 2           473747        1    prior             3                  3
# 3          2254736        1    prior             4                  4
# 4           431534        1    prior             5                  4
# ...            ...      ...      ...           ...                ...
# 32404854   1320836   202557    prior            17                  2
# 32404855     31526   202557    prior            18                  5
# 32404856    758936   203436    prior             1                  2
# 32404857   2745165   203436    prior             2                  3
# 32404858   3093936   205420    prior             1                  4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %%
path= r'C:\Users\hp\Desktop\Task 4\Task 4.2\Instacart Basket Analysis'

# %%
df = orders_products_merged[:1000000]

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
orders_products_merged['price_range'] = orders_products_merged.apply(price_label, axis=1)

# %%
orders_products_merged['price_range'].value_counts()
# Out:
# Mid-range product    21860860
# Low-range product    10126321
# High range             417678
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13056\1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %% [markdown]
# __If-Statements with For-Loops__

# %%
print('My age is 30')
# Out:
# My age is 30

# %%
print('My age is 31')
# Out:
# My age is 31

# %%
print('My age is 32')
# Out:
# My age is 32

# %%
for x in range (30, 45):
    print("my age is %d" % (x))
# Out:
# my age is 30
# my age is 31
# my age is 32
# my age is 33
# my age is 34
# my age is 35
# my age is 36
# my age is 37
# my age is 38
# my age is 39
# my age is 40
# my age is 41
# my age is 42
# my age is 43
# my age is 44

# %%
orders_products_merged['order_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: order_day_of_week, dtype: int64

# %%
result = []

for value in orders_products_merged['order_day_of_week']:
    if value == 0:
        result.append("Busiest day")
    elif value == 4:
        result.append("Least busy")
    else:
        result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
orders_products_merged['Busiest_day']=result

# %%
orders_products_merged['Busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: Busiest_day, dtype: int64

# %% [markdown]
# __Directions__

# %% [markdown]
# _The label should correspond with the two busiest days of the week as opposed to the single busiest day._

# %%
result2 = []

for value in orders_products_merged['order_day_of_week']:
    if value == 0 or value == 1:
        result2.append('Busiest day')
    elif value == 4 or value == 3:
        result2.append('slowest busy')
    else:
        result2.append('Regularly busy')

# %%
orders_products_merged['Busiest_days']=result2

# %%
result2
# Out:
# ['Regularly busy',
#  'slowest busy',
#  'slowest busy',
#  'slowest busy',
#  'slowest busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'slowest busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'slowest busy',
#  'slowest busy',
#  'slowest busy',
#  'slowest busy',
#  'slowest busy',
#  'slowest busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'slowest busy',
#  'Regularly busy',
#  'slowest busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'slowest busy',
#  'slowest busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'slowest busy',
# ...

# %%
orders_products_merged
# Out:
#           order_id  user_id eval_set  order_number  order_day_of_week  \
# 0          2539329        1    prior             1                  2
# 1          2398795        1    prior             2                  3
# 2           473747        1    prior             3                  3
# 3          2254736        1    prior             4                  4
# 4           431534        1    prior             5                  4
# ...            ...      ...      ...           ...                ...
# 32404854   1320836   202557    prior            17                  2
# 32404855     31526   202557    prior            18                  5
# 32404856    758936   203436    prior             1                  2
# 32404857   2745165   203436    prior             2                  3
# 32404858   3093936   205420    prior             1                  4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %% [markdown]
# __Question 4: When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”__

# %%
count_hours=orders_products_merged['order_hour_of_day'].value_counts()

# %%
count_hours
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
hour_category = []

for hour in orders_products_merged['order_hour_of_day']:
    if hour in [10, 11, 14, 15, 13, 12, 16, 9]:
        hour_category.append('Most orders')
    elif hour in [23, 6, 0, 1, 5, 2, 4, 3]:
        hour_category.append('Fewest orders')
    else:
        hour_category.append('Average orders')

# %%
orders_products_merged['busiest_period_of_day']=hour_category

# %%
orders_products_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: busiest_period_of_day, dtype: int64

# %%
orders_products_merged
# Out:
#           order_id  user_id eval_set  order_number  order_day_of_week  \
# 0          2539329        1    prior             1                  2
# 1          2398795        1    prior             2                  3
# 2           473747        1    prior             3                  3
# 3          2254736        1    prior             4                  4
# 4           431534        1    prior             5                  4
# ...            ...      ...      ...           ...                ...
# 32404854   1320836   202557    prior            17                  2
# 32404855     31526   202557    prior            18                  5
# 32404856    758936   203436    prior             1                  2
# 32404857   2745165   203436    prior             2                  3
# 32404858   3093936   205420    prior             1                  4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %% [markdown]
# __I will export in PKL format because it is easy to export because of the size.__

# %%
orders_products_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_deriving.pkl'))
