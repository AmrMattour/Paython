# %%
import pandas as pd
import numpy as np
import os

# %%
orders_products_merged = pd.read_pickle(r'C:\Users\hp\Desktop\Task 4\Task 4.2\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_merged_deriving.pkl')

# %%
path= r'C:\Users\hp\Desktop\Task 4\Task 4.2\Instacart Basket Analysis'

# %%
df = orders_products_merged[:1000000]

# %%
df.head(10)
# Out:
#    order_id  user_id eval_set  order_number  order_day_of_week  \
# 0   2539329        1    prior             1                  2
# 1   2398795        1    prior             2                  3
# 2    473747        1    prior             3                  3
# 3   2254736        1    prior             4                  4
# 4    431534        1    prior             5                  4
# 5   3367565        1    prior             6                  2
# 6    550135        1    prior             7                  1
# 7   3108588        1    prior             8                  1
# 8   2295261        1    prior             9                  1
# 9   2550362        1    prior            10                  4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     1.0         196                  1
# 1                  7                    15.0         196                  1
# ...

# %%
orders_products_merged.groupby('product_name')

# %% [markdown]
# __Q.2 In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe__

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %%
orders_products_merged.describe()
# Out:
#            order_id       user_id  order_number  order_day_of_week  \
# count  3.240486e+07  3.240486e+07  3.240486e+07       3.240486e+07
# mean   1.710745e+06  1.029372e+05  1.714230e+01       2.738867e+00
# std    9.872988e+05  5.946610e+04  1.753532e+01       2.090077e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00       0.000000e+00
# 25%    8.559470e+05  5.142200e+04  5.000000e+00       1.000000e+00
# 50%    1.711049e+06  1.026160e+05  1.100000e+01       3.000000e+00
# 75%    2.565499e+06  1.543890e+05  2.400000e+01       5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01       6.000000e+00
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count       3.240486e+07            3.240486e+07  3.240486e+07
# mean        1.342515e+01            1.045674e+01  2.559866e+04
# std         4.246380e+00            8.846237e+00  1.408400e+04
# min         0.000000e+00            0.000000e+00  1.000000e+00
# ...

# %% [markdown]
# __Q.3 Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code__

# %% [markdown]
# _The mean in subset is number 17 which has higher mean in the full dataframe as it shown above._

# %% [markdown]
# __Q.4 Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.__

# %%
orders_products_merged['max_order'] = orders_products_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %%
orders_products_merged.head(15)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_week  \
# 0    2539329        1    prior             1                  2
# 1    2398795        1    prior             2                  3
# 2     473747        1    prior             3                  3
# 3    2254736        1    prior             4                  4
# 4     431534        1    prior             5                  4
# 5    3367565        1    prior             6                  2
# 6     550135        1    prior             7                  1
# 7    3108588        1    prior             8                  1
# 8    2295261        1    prior             9                  1
# 9    2550362        1    prior            10                  4
# 10   2968173       15    prior            15                  1
# 11   1870022       15    prior            17                  2
# 12   1911383       15    prior            18                  2
# 13   2715276       15    prior            21                  1
# ...

# %%
orders_products_merged.head(100)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_week  \
# 0    2539329        1    prior             1                  2
# 1    2398795        1    prior             2                  3
# 2     473747        1    prior             3                  3
# 3    2254736        1    prior             4                  4
# 4     431534        1    prior             5                  4
# ..       ...      ...      ...           ...                ...
# 95   3226575      360    prior             1                  5
# 96   1469869      377    prior             3                  5
# 97   1927023      387    prior             2                  4
# 98    858092      420    prior             4                  1
# 99    119314      420    prior             5                  3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     1.0         196                  1
# ...

# %%
orders_products_merged.head(100)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_week  \
# 0    2539329        1    prior             1                  2
# 1    2398795        1    prior             2                  3
# 2     473747        1    prior             3                  3
# 3    2254736        1    prior             4                  4
# 4     431534        1    prior             5                  4
# ..       ...      ...      ...           ...                ...
# 95   3226575      360    prior             1                  5
# 96   1469869      377    prior             3                  5
# 97   1927023      387    prior             2                  4
# 98    858092      420    prior             4                  1
# 99    119314      420    prior             5                  3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     1.0         196                  1
# ...

# %%
orders_products_merged.loc[orders_products_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
orders_products_merged.loc[(orders_products_merged['max_order'] <= 40) & (orders_products_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
orders_products_merged.loc[orders_products_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
orders_products_merged[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# ...

# %%
orders_products_merged.shape
# Out:
# (32404859, 22)

# %% [markdown]
# __Q.5 The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.__

# %%
orders_products_merged.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %% [markdown]
# __Q.6 The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:__
#
# __1)If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”__
#
# __2)If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”__

# %%
#Create avg price
orders_products_merged['avg_price']=orders_products_merged.groupby('user_id').agg({'prices': ['mean']})

# %%
orders_products_merged.loc[orders_products_merged['avg_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
orders_products_merged.loc[orders_products_merged['avg_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
orders_products_merged.head(50)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_week  \
# 0    2539329        1    prior             1                  2
# 1    2398795        1    prior             2                  3
# 2     473747        1    prior             3                  3
# 3    2254736        1    prior             4                  4
# 4     431534        1    prior             5                  4
# 5    3367565        1    prior             6                  2
# 6     550135        1    prior             7                  1
# 7    3108588        1    prior             8                  1
# 8    2295261        1    prior             9                  1
# 9    2550362        1    prior            10                  4
# 10   2968173       15    prior            15                  1
# 11   1870022       15    prior            17                  2
# 12   1911383       15    prior            18                  2
# 13   2715276       15    prior            21                  1
# ...

# %% [markdown]
# __Q.7 In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:__
#
# __If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”__
#
# __If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”__
#
# __If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.__

# %%
# Create median_freq
orders_products_merged['median_freq']=orders_products_merged.groupby('user_id').agg({'days_since_prior_order': ['mean']})

# %%
orders_products_merged.loc[orders_products_merged['median_freq'] >= 20, 'order_freq'] = 'Non-frequent customer.'

# %%
orders_products_merged.loc[(orders_products_merged['median_freq'] > 10)  & (orders_products_merged['median_freq'] <= 20), 'order_freq']= 'Regular customer.'

# %%
orders_products_merged.loc[orders_products_merged['median_freq'] <= 10, 'order_freq'] = 'Frequent customer'

# %%
orders_products_merged.head(50)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_week  \
# 0    2539329        1    prior             1                  2
# 1    2398795        1    prior             2                  3
# 2     473747        1    prior             3                  3
# 3    2254736        1    prior             4                  4
# 4     431534        1    prior             5                  4
# 5    3367565        1    prior             6                  2
# 6     550135        1    prior             7                  1
# 7    3108588        1    prior             8                  1
# 8    2295261        1    prior             9                  1
# 9    2550362        1    prior            10                  4
# 10   2968173       15    prior            15                  1
# 11   1870022       15    prior            17                  2
# 12   1911383       15    prior            18                  2
# 13   2715276       15    prior            21                  1
# ...

# %% [markdown]
# __Import__

# %%
orders_products_merged.to_pickle(os.path.join(path,'02 Data','Prepared Data','orders_products_merged_aggregated.pkl'))
